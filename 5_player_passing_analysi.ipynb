# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.stats as stats
from scipy.stats import linregress, pearsonr
import plotly.express as px
import plotly.graph_objects as go
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score

# %%
player_passing_1 = pd.read_csv('players/player_premier_league_passing_type.csv')
player_passing_2 = pd.read_csv('players/player_premier_league_passing.csv')

# %%
player_passing_1.head()
# Out:
#    Unnamed: 0            Player   Nation    Pos         Squad  Age  \
# 0           0  Brenden Aaronson   us USA  MF,FW  Leeds United   21
# 1           1     George Abbott  eng ENG     MF     Tottenham   16
# 2           2         Che Adams  sct SCO     FW   Southampton   26
# 3           3       Tyler Adams   us USA     MF  Leeds United   23
# 4           4  Tosin Adarabioyo  eng ENG     DF        Fulham   24
#
#    90s_played  TotalAtt_Pass  TotalComp_Passes  Pass_Blocked  Live_Passes  \
# 0        26.4            797               592            27          711
# 1         0.0              1                 1             0            1
# 2        22.1            498               330            17          490
# 3        24.0           1343              1108            24         1271
# 4        23.2           1300              1066            10         1235
#
#    Dead_Passes  Switches_Pass  Cross_Passes
# 0           85              2            72
# ...

# %%
player_passing_2.head()
# Out:
#    Unnamed: 0            Player   Nation    Pos         Squad  Age  \
# 0           0  Brenden Aaronson   us USA  MF,FW  Leeds United   21
# 1           1     George Abbott  eng ENG     MF     Tottenham   16
# 2           2         Che Adams  sct SCO     FW   Southampton   26
# 3           3       Tyler Adams   us USA     MF  Leeds United   23
# 4           4  Tosin Adarabioyo  eng ENG     DF        Fulham   24
#
#    90s_played  TotalComp_Passes  TotalAtt_Pass  TotalPas_Rate  ...  \
# 0        26.4               592            797           74.3  ...
# 1         0.0                 1              1          100.0  ...
# 2        22.1               330            498           66.3  ...
# 3        24.0              1108           1343           82.5  ...
# 4        23.2              1066           1300           82.0  ...
#
#    LongPasses_Att  Assist  xAG   xA  Ast-xAG  KeyPas  PassinF3rd  PassinPen  \
# 0              65       3  4.2  2.6     -1.2      46          47         16
# ...

# %%
common_cols = player_passing_1.columns.intersection(player_passing_2.columns).tolist()
player_passing = pd.merge(player_passing_1, player_passing_2, on=common_cols)
player_passing = player_passing.drop(columns=['Unnamed: 0'])
player_passing.index = player_passing.index + 1
player_passing.head()
# Out:
#              Player   Nation    Pos         Squad  Age  90s_played  \
# 1  Brenden Aaronson   us USA  MF,FW  Leeds United   21        26.4
# 2     George Abbott  eng ENG     MF     Tottenham   16         0.0
# 3         Che Adams  sct SCO     FW   Southampton   26        22.1
# 4       Tyler Adams   us USA     MF  Leeds United   23        24.0
# 5  Tosin Adarabioyo  eng ENG     DF        Fulham   24        23.2
#
#    TotalAtt_Pass  TotalComp_Passes  Pass_Blocked  Live_Passes  ...  \
# 1            797               592            27          711  ...
# 2              1                 1             0            1  ...
# 3            498               330            17          490  ...
# 4           1343              1108            24         1271  ...
# 5           1300              1066            10         1235  ...
#
#    LongPasses_Att  Assist  xAG   xA  Ast-xAG  KeyPas  PassinF3rd  PassinPen  \
# 1              65       3  4.2  2.6     -1.2      46          47         16
# ...
